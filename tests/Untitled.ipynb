# %%
import cv2
from face_utils.detection import Detector

# %%
imgPath = "files/Obama.jpg"
img = cv2.imread(imgPath)
img= np.array(img)
model = Detector("hog")
out = (model.detect(img,2)) #using (x,y,w,h) return mode

# %%
from face_utils.cropping import cropping

# %%
Image.fromarray(cropping.crop(img,out,1,80,80))
# Out:
# <PIL.Image.Image image mode=RGB size=80x80 at 0x7F223806C410>
